# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
all_abstracts = pd.read_csv('abstract_writer_31_01.csv')
all_abstracts.head()
# Out:
#    keyword                                           abstract
# 0  Acetoin  Serratia marcescens is reported to possess the...
# 1  Acetoin  Acetoin (3-hydroxy-2-butanone) is an important...
# 2  Acetoin  A set of 917 wines of Czech origin were analys...
# 3  Acetoin  Microbial production of acetoin is eco-friendl...
# 4  Acetoin  In this study, physicochemical composition, ni...

# %%
with open('disease', encoding="utf8") as f:
    contents = f.readlines()

contents[1].split('ENTRY')

disease_list = []
for i in range(1, len(contents)):
    if(contents[i][:4] == 'NAME'):
        first_prep = re.sub(r'[^a-zA-Z0-9]', ' ', contents[i].split('NAME')[-1].split(', including')[0].strip())
        first_prep = first_prep.split(' ')
        first_prep = [x for x in first_prep if x != '']
        second_prep = ' '.join(first_prep)
        disease_list.append(second_prep)
        
print(len(disease_list), disease_list[:5])
# Out:
# 1413 ['Acute lymphoblastic leukemia ALL precursor B lymphoblastic leukemia', 'Acute lymphoblastic leukemia ALL precursor T lymphoblastic leukemia', 'Acute myeloid leukemia AML', 'Chronic myeloid leukemia CML', 'Chronic lymphocytic leukemia CLL']

# %%
# Filter this data by keeping only those abstracts with any disease keyword in them
filter_index = [] # Will contain abstract index of interest
for i in range(len(all_abstracts)):
    current_abst = all_abstracts.iloc[i]['abstract']
    for disease in disease_list:
        if(disease in str(current_abst)):
            filter_index.append(i)
    if(i%10000 == 0):
        print('At ', i , ' Found len', len(filter_index))
            # print('Index ', i , 'Found word ', disease)
# Out:
# At  0  Found len 0
# At  10000  Found len 255
# At  20000  Found len 523
# At  30000  Found len 790
# At  40000  Found len 1069
# At  50000  Found len 1374
# At  60000  Found len 1635
# At  70000  Found len 1845
# At  80000  Found len 2142
# At  90000  Found len 2451

# %%
abstract_oint = all_abstracts.iloc[filter_index]
abstract_oint = abstract_oint.reset_index().drop('index', axis=1)
print(abstract_oint.head())
# Out:
#        keyword                                           abstract
# 0     Baclofen  Cerebral palsy (CP) is a chronic congenital di...
# 1  Pramipexole  Tourette syndrome (TS) is a neurodevelopmental...
# 2  Repaglinide  Objectives:\n        \n      \n      To assess...
# 3  Repaglinide  Objectives:\n        \n      \n      To assess...
# 4   Tymazoline  Objectives:\n        \n      \n      To assess...

# %%
abstract_oint.to_csv('abstract_oi.csv', index=False)

# %%
# New task: To get counts of abstracts for each disease name. Use the 90k abstracts file, and get counts for each disease
disease_abstract_count = {}
for dn in disease_list:
    disease_abstract_count[dn] = 0

for i in range(len(all_abstracts)):
    if(i%1000 == 0):
        print(i)
    current_abst = all_abstracts.iloc[i]['abstract']
    for dn in disease_list:
        if(dn in str(current_abst)):
            if(not disease_abstract_count.get(dn)):
                disease_abstract_count[dn] = 1
            else:
                disease_abstract_count[dn]+=1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000

# %%
disease_abstract_count
# Out:
# {'Acute lymphoblastic leukemia ALL precursor B lymphoblastic leukemia': 0,
#  'Acute lymphoblastic leukemia ALL precursor T lymphoblastic leukemia': 0,
#  'Acute myeloid leukemia AML': 0,
#  'Chronic myeloid leukemia CML': 0,
#  'Chronic lymphocytic leukemia CLL': 0,
#  'Hairy cell leukemia': 14,
#  'Hodgkin lymphoma': 132,
#  'Burkitt lymphoma': 7,
#  'Adult T cell leukemia': 5,
#  'Multiple myeloma': 24,
#  'Lymphoplasmacytic lymphoma': 0,
#  'Polycythemia vera': 7,
#  'Small cell lung cancer': 13,
#  'Non small cell lung cancer': 0,
#  'Malignant pleural mesothelioma': 14,
#  'Oral cancer': 6,
#  'Esophageal cancer': 9,
#  'Gastric cancer': 19,
#  'Pancreatic cancer': 33,
#  'Colorectal cancer': 55,
#  'Renal cell carcinoma': 10,
#  'Bladder cancer': 15,
#  'Testicular cancer': 1,
#  'Prostate cancer': 61,
#  'Penile cancer': 0,
#  'Endometrial Cancer': 1,
#  'Ovarian cancer': 20,
#  'Choriocarcinoma': 2,
#  'Vulvar cancer': 0,
#  'Cervical cancer': 20,
#  'Breast cancer': 114,
#  'Thyroid cancer': 6,
#  'Adrenal carcinoma': 0,
#  'Carcinoid': 2,
#  'Ewing s sarcoma': 0,
#  'Osteosarcoma': 30,
#  'Alveolar rhabdomyosarcoma': 0,
#  'Malignant melanoma': 3,
#  'Basal cell carcinoma': 4,
#  'Squamous cell carcinoma': 3,
#  'Kaposi s sarcoma': 0,
#  'Glioma': 26,
#  'Neuroblastoma': 17,
#  'Cancer of the anal canal': 0,
#  'Malignant islet cell carcinoma': 0,
#  'Cholangiocarcinoma': 4,
#  'Gallbladder cancer': 2,
#  'Hepatocellular carcinoma': 63,
#  'Myxoid liposarcoma': 3,
#  'Synovial sarcoma': 5,
#  'Alveolar soft part sarcoma': 0,
#  'Clear cell sarcoma of soft tissue': 0,
#  'Extraskeletal myxoid chondrosarcoma': 0,
#  'Nasopharyngeal cancer': 2,
#  'Laryngeal cancer': 0,
#  'Alzheimer s disease AD': 0,
#  'Parkinson s disease PD': 0,
#  'Amyotrophic lateral sclerosis ALS': 0,
#  'Huntington s disease HD': 0,
#  'Dentatorubropallidoluysian atrophy DRPLA': 0,
#  'Prion diseases': 10,
#  'Spinal and bulbar muscular atrophy SBMA': 0,
#  'Spinocerebellar ataxia SCA': 0,
#  'Ataxia telangiectasia AT': 0,
#  'Alexander disease': 1,
#  'Lewy body dementia LBD': 0,
#  'Friedreich ataxia': 4,
#  'Leber optic atrophy': 0,
#  'Glycogen storage diseases GSD': 0,
#  'Galactosemia': 2,
#  'Hereditary fructose intolerance': 0,
#  'Pyruvate dehydrogenase complex deficiency': 0,
#  'Pyruvate carboxylase deficiency': 0,
#  'Canavan disease CD': 0,
#  'Refsum disease': 2,
#  'Cockayne syndrome': 0,
#  'Progressive supranuclear palsy PSP': 0,
#  'Frontotemporal lobar degeneration FTLD': 0,
#  'Asthma': 164,
#  'Systemic lupus erythematosus': 19,
#  'Hashimoto s thyroiditis': 0,
#  'Graves disease': 13,
#  'Allograft rejection': 0,
#  'Graft versus host disease': 1,
#  'Agammaglobulinemias': 0,
#  'Hyper IgM syndromes autosomal recessive type': 0,
#  'Other humoral immunodeficiencies': 0,
#  'Common variable immunodeficiency CVID': 0,
#  'IFN gamma IL 12 axis': 0,
#  'NK cell defects': 0,
#  'T B Severe combined immunodeficiencies SCIDs': 0,
#  'Combined immunodeficiencies CIDs': 0,
#  'Immunodeficiency associated with DNA repair defects': 0,
#  'Ectodermal dysplasia associated immunodeficiency EDA ID': 0,
#  'Defects of toll like receptor signaling': 0,
#  'Chemokine receptor defect': 0,
#  'Chronic granulomatous disease': 0,
#  'Leukocyte adhesion deficiency LAD': 0,
#  'Neutropenic disorders': 0,
#  'Other phagocyte defects': 0,
#  'Classic complement pathway component defects': 0,
#  'Late complement pathway defects': 0,
#  'Alternative complement pathway component defects': 0,
#  'Mannose binding lectin pathway component defects': 0,
#  'Complement regulatory protein defects': 0,
#  'Other well defined immunodeficiency syndromes': 0,
#  'Autoimmune lymphoproliferative syndromes ALPS': 0,
#  'Familial hemophagocytic lymphohistiocytosis FHPL': 0,
#  'Cholera': 5,
#  'Typhoid fever': 2,
#  'Paratyphoid fever': 0,
#  'Salmonellosis': 3,
#  'Fructose 1 6 bisphosphatase deficiency': 0,
#  'Congenital sucrase isomaltase deficiency': 0,
#  'Congenital lactase deficiency': 0,
#  'Primary hyperoxaluria HP': 0,
#  'Congenital disorders of glycosylation CDG type I': 0,
#  'Congenital disorders of glycosylation CDG type II': 0,
#  'Dystroglycanopathy': 3,
#  'Multiple exostoses': 0,
#  'Mucopolysaccharidosis type IV MPS4': 0,
#  'GM2 gangliosidoses': 1,
#  'Fabry disease': 6,
#  'Gaucher disease': 14,
#  'Metachromatic leukodystrophy MLD': 0,
#  'Mucopolysaccharidosis type I MPS1': 0,
#  'Mucopolysaccharidosis type II MPS2': 0,
#  'Mucopolysaccharidosis type III MPS3': 0,
#  'Mucopolysaccharidosis type VI MPS6': 0,
#  'Mucopolysaccharidosis type VII MPS7': 0,
#  'Mucopolysaccharidosis type IX MPS9': 0,
#  'X linked ichthyosis XLI': 0,
#  'Krabbe disease': 2,
#  'Niemann Pick disease type C NPC': 0,
#  'Niemann Pick disease NPD typeA and B': 0,
#  'Farber lipogranulomatosis': 0,
#  'alpha Mannosidosis': 0,
#  'beta Mannosidosis': 0,
#  'Fucosidosis': 0,
#  'Sialidosis': 0,
#  'Mucolipidosis II and III': 0,
#  'Mucolipidosis IV': 0,
#  'Aspartylglucosaminuria AGU': 0,
#  'Alpha N acetylgalactosaminidase deficiency': 0,
#  'Sialuria Sialic acid storage disease': 0,
#  'Lysosomal acid lipase deficiency': 0,
#  'Neuronal ceroid lipofuscinosis': 0,
#  'Danon disease': 1,
#  'Cerebrotendinous xanthomatosis': 1,
#  'Sitosterolemia': 3,
#  'Familial combined hyperlipidemia FCHL': 0,
#  'Hyperlipoproteinemia type I': 0,
#  'Hypercholesterolemia': 6,
#  'Hyperlipoproteinemia type III': 0,
#  'Hyperlipoproteinemia type V': 0,
#  'Lecithin cholesterol acyltransferase deficiency': 0,
#  'Tangier disease': 2,
#  'Abetalipoproteinemia': 0,
#  'Smith Lemli Opitz syndrome': 0,
#  'Sjogren Larsson syndrome': 0,
#  'Alkaptonuria': 20,
#  'Carbamoyl phosphate synthetase I deficiency': 0,
#  'Tyrosinemia': 14,
#  'Hermansky Pudlak syndrome HPS': 0,
#  'Phenylketonuria PKU': 0,
#  'Oculocutaneous albinism OCA': 0,
#  'Ocular albinism': 0,
#  'Piebaldism': 0,
#  'Histidinemia': 0,
#  'Maple syrup urine disease MSUD': 0,
#  'Isovaleric acidemia IVA': 0,
#  'Methylmalonic aciduria MMA': 0,
#  'Propionic acidemia': 2,
#  'Adrenoleukodystrophy ALD': 0,
#  'Adrenoleukodystrophy neonatal NALD': 0,
#  'Glutaric acidemia': 0,
#  '3 Hydroxy 3 methylglutaryl CoA lyase deficiency': 0,
#  'Holocarboxylase synthetase deficiency': 0,
#  '3 Methylcrotonylglycinuria': 0,
#  'Cystathioninuria': 0,
#  'Homocystinuria': 2,
#  'Hypermethioninemia': 0,
#  'Citrullinemia CTLN': 0,
#  'Hyperargininemia': 0,
#  'Ornithine transcarbamylase deficiency': 1,
#  'Hyperlysinemia': 0,
#  'Ornithinaemia': 0,
#  'Hyperprolinemia HP': 0,
#  'Nonketotic hyperglycinemia': 1,
#  'Xanthinuria': 0,
#  'Dihydropyrimidine dehydrogenase deficiency': 0,
#  'Lesch Nyhan syndrome': 0,
#  'Adenine phosphoribosyltransferase deficiency': 0,
#  'Phosphoribosylpyrophosphate synthetase I superactivity': 0,
#  'Adenylosuccinate lyase deficiency': 1,
#  'Orotic aciduria': 0,
#  'Dihydropyrimidinase deficiency': 0,
#  'Beta ureidopropionase deficiency': 0,
#  'Erythropoietic porphyria EP': 0,
#  'Hepatic porphyria': 8,
#  'Acatalasia': 0,
#  'Infantile Refsum disease IRD': 0,
#  'Peroxisome biogenesis disorder': 0,
#  'Mevalonate kinase deficiency': 0,
#  'Rhizomelic chondrodysplasia punctata': 2,
#  'Hyperbilirubinemia': 9,
#  'Menkes disease MD': 0,
#  'Wilson disease': 14,
#  'Hemochromatosis HFE': 0,
#  'Acrodermatitis enteropathica AEZ': 0,
#  'Hypophosphatasia': 4,
#  'Hypophosphatemic rickets': 1,
#  'Periodic paralysis': 0,
#  'Congenital adrenal hyperplasia CAH': 0,
#  'Pulmonary surfactant metabolism dysfunction SMDP': 0,
#  'Cystic fibrosis CF': 0,
#  'Hemophilia': 1,
#  'Factor V deficiency': 0,
#  'Combined deficiency of factors V and VIII F5F8D': 0,
#  'Afibrinogenemia': 0,
#  'Inherited thrombophilia': 0,
#  'Bernard Soulier syndrome': 1,
#  'Thrombotic thrombocytopenic purpura': 1,
#  'Glanzmann thrombasthenia': 0,
#  'Congenital amegakaryocytic thrombocytopenia CAMT': 0,
#  'Thalassemia': 10,
#  'Sickle cell anemia SCA': 0,
#  'Hereditary spherocytosis SPH': 0,
#  'Hereditary elliptocytosis HE': 0,
#  'Hereditary stomatocytosis HSt': 0,
#  'Macrothrombocytopenia': 0,
#  'Pelger Huet anomaly': 0,
#  'Methemoglobinemia': 17,
#  'Congenital polycythemia': 0,
#  'Diamond Blackfan anemia DBA': 0,
#  'Fanconi anemia': 9,
#  'Bartter syndrome': 0,
#  'Gitelman syndrome': 3,
#  'Combined proximal and distal renal tubular acidosis RTA type 3': 0,
#  'Liddle syndrome': 5,
#  'Hyperkalemic distal renal tubular acidosis RTA type 4': 0,
#  'Pseudohypoparathyroidism': 0,
#  'Familial hypocalciuric hypercalcemia FHH1': 0,
#  'Primary hyperparathyroidism': 14,
#  'Thyroid hormone resistance syndrome': 0,
#  'Congenital nongoitrous hypothyroidism CHNG': 0,
#  'Thyroid dyshormonogenesis': 0,
#  'Congenital nephrogenic diabetes insipidus NDI': 0,
#  'Neurohypophyseal diabetes insipidus NPDI': 0,
#  'Pituitary Dwarfism PD': 0,
#  'Hypogonadotropic hypogonadism': 1,
#  'Familial glucocorticoid deficiency FGD': 0,
#  'Achalasia Addisonianism Alacrima syndrome': 0,
#  'Aldosterone synthase deficiency': 0,
#  'Apparent mineralocorticoid excess syndrome': 0,
#  'Pigmented micronodular adrenocortical disease PPNAD': 0,
#  'Meckel syndrome MKS': 0,
#  'Spina bifida': 0,
#  'Acrocallosal syndrome': 0,
#  'Charcot Marie Tooth disease CMT': 0,
#  'Hereditary sensory and autonomic neuropathy HSAN': 0,
#  'Hereditary spastic paraplegia SPG': 0,
#  'Holoprosencephaly HPE': 0,
#  'Lissencephaly LIS': 0,
#  'Primary microcephaly MCPH': 0,
#  'Periventricular nodular heterotopia PVNH': 0,
#  'Polymicrogyria': 1,
#  'Multiple sulfatase deficiency MSD': 0,
#  'Pycnodysostosis': 0,
#  'Papillon Lefevre syndrome': 0,
#  'Cystinosis': 19,
#  'Galactosialidosis': 0,
#  'Enterohemorrhagic Escherichia coli EHEC infection': 0,
#  'Enteropathogenic Escherichia coli EPEC infection': 0,
#  'Uropathogenic Escherichia coli UPEC infection': 0,
#  'Enterotoxigenic Escherichia coli ETEC infection': 0,
#  'GM1 gangliosidosis': 7,
#  'Cryopyrin associated periodic syndrome CAPS': 0,
#  'Ebola haemorrhagic fever': 0,
#  'Crimean Congo hemorrhagic fever': 1,
#  'Blau syndrome': 1,
#  'Crohn s disease': 0,
#  'Pyogenic sterile arthritis pyoderma gangrenosum and acne PAPA syndrome': 0,
#  'Familial Mediterranean fever FMF': 0,
#  'Recurrent hydatidiform moles RHM': 0,
#  'Aicardi Goutieres Syndrome AGS': 0,
#  'Familial chilblain lupus FCL': 0,
#  'Hypertrophic cardiomyopathy HCM': 0,
#  'Arrhythmogenic right ventricular cardiomyopathy ARVC': 0,
#  'Dilated cardiomyopathy DCM': 0,
#  'Viral myocarditis': 1,
#  'Defects in RecQ helicases': 0,
#  'Plague': 1,
#  'Yersiniosis': 0,
#  'Shigellosis': 4,
#  'Enterobacter infection': 0,
#  'Klebsiella infection': 1,
#  'Citrobacter infection': 0,
#  'Serratia infection': 0,
#  'Haemophilus influenzae infection': 0,
#  'Chancroid': 0,
#  'Pasteurellosis': 0,
#  'Vibrio parahaemolyticus infection': 0,
#  'Vibrio vulnificus infection': 2,
#  'Multidrug resistant Acinetobacter infection': 0,
#  'Q fever': 4,
#  'Legionellosis': 0,
#  'Tularemia': 2,
#  'Multidrug resistant Pseudomonas aeruginosa infection': 0,
#  'Meningococcal infections': 0,
#  'Gonococcal infections': 1,
#  'Glanders': 0,
#  'Melioidosis': 4,
#  'Pertussis': 1,
#  'Helicobacter pylori infection': 30,
#  'Campylobacter infection': 1,
#  'Typhus fever': 1,
#  'Spotted fever': 0,
#  'Scrub typhus': 2,
#  'Brucellosis': 6,
#  'Bartonellosis': 1,
#  'Trench fever': 0,
#  'Anthrax': 5,
#  'Foodborne Bacillus cereus intoxication': 0,
#  'Methicillin resistant Staphylococcal aureus MRSA infection': 0,
#  'Vancomycin resistant Staphylococcal aureus VRSA infection': 0,
#  'Listeriosis': 1,
#  'Streptococcal infection': 0,
#  'Bacterial endocarditis': 1,
#  'Foodborne Clostridium perfringens intoxication': 0,
#  'Gas gangrene': 0,
#  'Tetanus': 1,
#  'Pseudomembranous colitis': 0,
#  'Botulism': 0,
#  'Vancomycin resistant enterococci infection': 0,
#  'Mycoplasma pneumonia': 14,
#  'Tuberculosis': 136,
#  'Diphtheria': 1,
#  'Leprosy': 13,
#  'Nocardiosis': 0,
#  'Extrinsic allergic alveolitis EAA': 0,
#  'Chlamydia infection': 0,
#  'Lymphogranuloma venereum': 0,
#  'Trachoma': 0,
#  'Psittacosis': 0,
#  'Chlamydial pneumonia': 0,
#  'Whipple s disease': 0,
#  'Borreliosis': 0,
#  'Syphilis': 4,
#  'Leptospirosis': 2,
#  'Cryptosporidiosis': 0,
#  'African trypanosomiasis': 21,
#  'Chagas disease': 41,
#  'Leishmaniasis': 44,
#  'Amoebiasis': 3,
#  'Malaria': 148,
#  'Giardiasis': 8,
#  'Candidiasis': 12,
#  'Cryptococcosis': 8,
#  'Herpes simplex infection': 0,
#  'Varicella': 9,
#  'Infectious mononucleosis': 0,
#  'Cytomegalovirus infection': 0,
#  'Exanthema subitum': 0,
#  'Progressive multifocal leukoencephalopathy PML': 0,
#  'Adenovirus infection': 6,
#  'Smallpox': 1,
#  'Monkeypox': 1,
#  'Viral wart': 0,
#  'Acute poliomyelitis': 0,
#  'Rabies': 4,
#  'Lyssavirus infection': 0,
#  'Mosquito borne viral encephalitis': 0,
#  'Tick borne viral encephalitis': 0,
#  'Dengue': 18,
#  'Mosquito borne viral fevers': 0,
#  'Arthropod borne viral fevers': 0,
#  'Yellow fever': 0,
#  'South American new world arenaviral hemorrhagic fevers': 0,
#  'Lassa fever': 5,
#  'B virus infection': 13,
#  'Non chlamydial non gonococcal urethritis': 0,
#  'Hemorrhagic fever with renal syndrome HFRS': 0,
#  'Hantavirus pulmonary syndrome HPS': 0,
#  'Henipavirus infection': 0,
#  'Enterovirus infection': 0,
#  'Measles': 5,
#  'Rubella': 2,
#  'Mumps': 3,
#  'Ross River fever': 0,
#  'Influenza': 85,
#  'Avian influenza': 0,
#  'Parainfluenza infections': 0,
#  'Respiratory syncytial virus infection': 0,
#  'Severe acute respiratory syndrome': 39,
#  'Disorders of nucleotide excision repair': 0,
#  'Erythema infectiosum': 0,
#  'Marburg disease': 0,
#  'Acquired immunodeficiency syndrome AIDS': 0,
#  'Peroxisomal beta oxidation enzyme deficiency': 0,
#  'Type I diabetes mellitus': 0,
#  'Type II diabetes mellitus': 0,
#  'Maturity onset diabetes of the young MODY': 0,
#  'Hepatitis A': 3,
#  'Hepatitis B': 48,
#  'Hepatitis C': 29,
#  'Hepatitis D': 0,
#  'Hepatitis E': 9,
#  'Omsk hemorrhagic fever': 0,
#  'Alstrom syndrome AS': 0,
#  'Bardet Biedl syndrome BBS': 0,
#  'Congenital generalized lipodystrophy CGL': 0,
#  'Familial partial lipodystrophy FPL': 0,
#  'Mucopolysaccharidosis MPS': 0,
#  'Glycoproteinoses': 0,
#  'Defects in the degradation of sulfatide': 0,
#  'Defects in the degradation of sphingomyelin': 0,
#  'Lysosomal cysteine protease deficiencies': 0,
#  'Defects in the degradation of ganglioside': 0,
#  'Relapsing fever': 0,
#  'Distal renal tubular acidosis RTA type 1': 0,
#  'Proximal renal tubular acidosis RTA type 2': 0,
#  'Fibrodysplasia ossificans progressiva FOP': 0,
#  'Ossification of the posterior longitudinal ligament of spine OPLL': 0,
#  'Hereditary dentine disorders': 0,
#  'Holt Oram syndrome': 0,
#  'Camurati Engelmann disease': 0,
#  'Toxoplasmosis': 3,
#  'Osteopetrosis': 1,
#  'Paget s disease of bone and related disorders': 0,
#  'Polycystic lipomembranous osteodysplasia with sclerosing leukoencephalopathy PLOSL': 0,
#  'Shwachman Diamond syndrome SDS': 0,
#  'Rett syndrome': 13,
#  'Progressive osseous heteroplasia POH': 0,
#  'Campomelic dysplasia CD': 0,
#  'Osteoglophonic dysplasia OD': 0,
#  'Osteopathia striata with cranial sclerosis': 0,
#  'Osteoarthritis with mild chondrodysplasia': 0,
#  'Craniofacial deafness hand syndrome': 0,
#  'HEM skeletal dysplasia': 0,
#  'Familial osteochondritis dissecans': 0,
#  'Oculodentodigital dysplasia': 0,
#  'Sclerosing bone dysplasias': 0,
#  'Osteoporosis pseudoglioma syndrome OPPG': 0,
#  'Disorders caused by loss of function of LEMD3': 0,
#  'Contiguous gene deletion syndrome involving EYA1': 0,
#  'Oral facial digital syndrome': 0,
#  'Spinal muscular atrophy SMA': 0,
#  'Fronto Otopalatodigital Osteodysplasia': 0,
#  'Primary hypertrophic osteoarthropathy PHO': 0,
#  'Craniosynostosis': 1,
#  'Synpolydactyly': 0,
#  'Hand foot genital syndrome': 0,
#  'FLNB related disorders': 0,
#  'Stuve Wiedemann syndrome': 0,
#  'Currarino syndrome': 0,
#  'Patella dysplasias': 0,
#  'Fragile X Syndrome': 2,
#  'Grebe dysplasia': 0,
#  'Fibular hypoplasia and complex brachydactyly': 0,
#  'Acromesomelic dysplasia with genital anomalies': 0,
#  'Mitochondrial DNA depletion syndrome MDS': 0,
#  'Acromesomelic dysplasia Maroteaux type': 0,
#  'Split hand foot malformation SHFM': 0,
#  'Torg Winchester syndrome': 0,
#  'Mitochondrial respiratory chain deficiencies MRCD': 0,
#  'Schneckenbecken dysplasia': 0,
#  'Enlarged parietal foramina cranium bifidum': 0,
#  'Multiple epiphyseal dysplasia MED': 0,
#  'Pseudoachondroplasia PSACH': 0,
#  'Prader Willi and Angelman syndromes': 0,
#  'Metaphyseal dysplasias': 0,
#  'Non syndromic X linked mental retardation': 0,
#  'Cone rod dystrophy and cone dystrophy': 0,
#  'Brachydactyly': 0,
#  'Other brachydactylies': 0,
#  'Robinow syndrome': 0,
#  'SOST related disorders': 0,
#  'Trichodentoosseous dysplasia': 0,
#  'Diaphyseal dysplasia with anemia Ghosal': 0,
#  'Craniometaphyseal dysplasia': 0,
#  'SHOX related haploinsufficiency disorders': 0,
#  'Heparan sulfate proteoglycan gene defects': 0,
#  'Desbuquois syndrome': 0,
#  'Eiken dysplasia': 0,
#  'Congenital hemidysplasia with ichthyosiform nevus and limb defects CHILD': 0,
#  'Cherubism': 2,
#  'Gnathodiaphyseal dysplasia': 0,
#  'Spondylocarpotarsal synostosis syndrome': 0,
#  'Keutel syndrome': 0,
#  'Fibrous dysplasia polyostotic': 0,
#  'Pallister Hall syndrome': 0,
#  'EVC related disorders': 0,
#  'Rubinstein Taybi syndrome': 0,
#  'FGFR3 related short limb skeletal dysplasias': 0,
#  'Osteogenesis imperfecta': 7,
#  'Dyskeratosis congenita DC': 0,
#  'Blomstrand syndrome': 0,
#  '3M syndrome': 0,
#  'Feingold syndrome': 0,
#  'Short rib polydactyly syndrome': 0,
#  'Permanent neonatal diabetes mellitus PNDM': 0,
#  'Transient neonatal diabetes mellitus TNDM': 0,
#  'Bruck syndrome': 1,
#  'The DTDST related disorders': 0,
#  'Isolated orofacial clefts': 0,
#  'Spondylocostal dysostosis SCD': 0,
#  'RMRP related disorders': 0,
#  'Type XI collagenopathies': 0,
#  'Type II collagenopathies': 0,
#  'Cleidocranial dysplasia': 0,
#  'TRPV4 related skeletal dysplasias': 0,
#  'Noonan syndrome and related disorders': 0,
#  'TRPV4 related peripheral neuropathies': 0,
#  'Disorders of fatty acid oxidation': 0,
#  'Camptodactyly arthropathy coxa vara pericarditis syndrome': 0,
#  'Retinitis pigmentosa RP': 0,
#  'Frontonasal dysplasia': 0,
#  'Cranioectodermal dysplasia': 0,
#  'Joubert syndrome': 0,
#  'Venous malformations': 2,
#  'RASA1 related disorders': 0,
#  'Hereditary hemorrhagic telangiectasia HHT': 0,
#  'Cerebral cavernous malformation': 0,
#  'Lymphedemas': 0,
#  'Cerebral autosomal dominant arteriopathy with subcortical infarcts and leucoencephalopathy CADASIL': 0,
#  'Nephronophthisis medullary cystic kidney disease': 0,
#  'Senior Loken syndrome': 0,
#  'PTEN hamartoma tumor syndrome PHTS': 0,
#  'Osteoporosis lymphedema anhydrotic ectodermal dysplasia with immunodeficiency OLEDAID': 0,
#  'Uromodulin associated kidney diseases': 0,
#  'Polycystic kidney disease': 0,
#  'Renal hepatic pancreatic dysplasia': 0,
#  'Septo optic dysplasia': 0,
#  'Polycystic liver disease': 0,
#  'Atrial septal defect': 0,
#  'Atrioventricular septal defect': 0,
#  'Brunner syndrome': 0,
#  'Tetralogy of Fallot': 0,
#  'Transposition of great arteries': 0,
#  'Alagille syndrome': 0,
#  'Glycerol kinase deficiency GKD': 0,
#  'Congenital supravalvar aortic stenosis': 0,
#  'Bicuspid aortic valve': 1,
#  'Char syndrome': 0,
#  'CHARGE syndrome': 1,
#  'Cutis laxa': 0,
#  'Geroderma osteodysplasticum': 0,
#  'von Hippel Lindau syndrome': 0,
#  'Pseudoxanthoma elasticum': 1,
#  'Brachydacytly mental retardation syndrome and Smith Magenis syndrome': 0,
#  'Dystrophinopathies': 0,
#  'Emery Dreifuss muscular dystrophy': 0,
#  'Primary ciliary dyskinesia': 1,
#  'Sarcoglycanopathies': 0,
#  'Dysferlinopathies': 0,
#  'Caveolinopathies': 0,
#  'Myotonic dystrophy DM': 0,
#  'Aarskog Scott syndrome': 0,
#  'Kabuki syndrome': 2,
#  'Johanson Blizzard syndrome': 0,
#  'ESCO2 related disorders': 0,
#  'Townes Brocks syndrome': 0,
#  'Coffin Lowry syndrome CLS': 0,
#  'Renal tubular dysgenesis': 0,
#  'Pierson syndrome': 0,
#  'Syndromic X linked mental retardation with epilepsy or seizures': 0,
#  'MYH9 related kidney diseases': 0,
#  'Hereditary angiopathy with nephropathy aneurysms and muscle cramps HANAC': 0,
#  'Schimke immunoosseous dysplasia': 1,
#  'Alport syndrome': 2,
#  'Benign familial hematuria': 0,
#  'Opitz GBBB syndrome': 0,
#  'Epidermolysis bullosa simplex': 0,
#  'Epidermolysis bullosa hemidesmosomal': 0,
#  'Epidermolysis bullosa junctional': 0,
#  'Epidermolysis bullosa dysprophica': 0,
#  'Kindler syndrome': 0,
#  'Familial exudative vitreoretinopathy FEVR': 0,
#  'Congenital muscular dystrophies CMD MDC': 0,
#  'Facioscapulohumeral muscular dystrophy FSHD': 0,
#  'Calpainopathy': 0,
#  'Limb girdle muscular dystrophy LGMD': 0,
#  'Distal muscular dystrophies': 0,
#  'Myofibrillar myopathies MFM': 0,
#  'Nonaka distal myopathy NM': 0,
#  'Snyder Robinson syndrome': 0,
#  '46 XX disorders of sex development Disorders of gonadal development': 0,
#  '46 XX disorders of sex development Disorders related to androgen excess': 0,
#  '46 XX disorders of sex development Other': 0,
#  'Hutchinson Gilford progeria syndrome': 0,
#  'Glucocorticoid remediable aldosteronism GRA': 0,
#  'Hypertension exacerbated in pregnancy': 0,
#  'Deafness autosomal dominant': 0,
#  'Deafness autosomal recessive': 0,
#  'Early infantile epileptic encephalopathy': 0,
#  '46 XY disorders of sex development Disorders of gonadal development': 0,
#  '46 XY disorders of sex development Disorders in androgen synthesis or action': 0,
#  '46 XY disorders of sex development Other': 0,
#  'Treacher Collins syndrome': 0,
#  'IRF6 related disorders': 0,
#  'Primary open angle glaucoma': 2,
#  'Infantile cortical hyperostosis': 0,
#  'Infantile systemic hyalinosis and juvenile hyaline fibromatosis': 0,
#  'Amelogenesis imperfecta': 0,
#  'Bowen Conradi syndrome BCS': 0,
#  'Desmosterolosis': 1,
#  'Amelogenesis imperfecta hypoplastic hypomaturation with taurodontism AIHHT': 0,
#  'Kenny Caffey syndrome': 0,
#  'Axenfeld Rieger syndrome ARS': 0,
#  'Alopecia neurologic defects and endocrinopathy syndrome ANE syndrome': 0,
#  'Hypoparathyroidism retardation dysmorphism syndrome': 0,
#  'Hajdu Cheney syndrome': 0,
#  'Familial cholestasis': 0,
#  'Tooth agenesis': 0,
#  'Nephrotic syndrome and focal segmental glomerulosclerosis': 0,
#  'Premature ovarian failure': 0,
#  'Congenital bile acid synthesis defect CBAS': 0,
#  'Acheiropodia': 0,
#  'Rheumatoid arthritis': 35,
#  'Cornelia de Lange syndrome CdLS': 0,
#  'Heterotaxy': 0,
#  'Duane retraction syndrome': 0,
#  'Duane radial ray syndrome and IVIC syndrome': 0,
#  'Aniridia': 0,
#  'Tetra amelia': 0,
#  'Ulnar mammary syndrome': 0,
#  'Ectrodactyly ectodermal dysplasia cleft palate syndrome EEC syndrome': 0,
#  'Ectodermal dysplasia ectrodactyly and macular dystrophy EEM syndrome': 0,
#  'Limb mammary syndrome': 0,
#  'ADULT syndrome': 0,
#  'Lacrimo auriculo dento digital syndrome LADD': 0,
#  'Tooth and nail syndrome': 0,
#  'Ectodermal dysplasia skin fragility syndrome': 0,
#  'Incontinentia pigmenti': 1,
#  'Odontoonychodermal dysplasia': 0,
#  'Ectodermal dysplasia syndactyly syndrome EDSS': 0,
#  'Ectodermal dysplasia hidrotic': 0,
#  'Ectodermal dysplasia pure hair nail type HNED': 0,
#  'Allan Herndon Dudley syndrome': 0,
#  'Ectodermal dysplasia': 0,
#  'Solitary median maxillary central incisor syndrome': 0,
#  'Marfan syndrome': 9,
#  'Barth syndrome BTHS': 0,
#  'McLeod syndrome': 0,
#  'Scapuloperoneal myopathy SPM': 0,
#  'Reducing body myopathy RBM': 0,
#  'Syndromic X linked mental retardation': 0,
#  'Shprintzen Goldberg syndrome': 0,
#  'Congenital contractural arachnodactyly CCA': 0,
#  'MASS phenotype': 0,
#  'Ectopia lentis': 0,
#  'Restrictive dermopathy': 0,
#  'Anemia due to disorders of glycolytic enzymes': 0,
#  'Mandibuloacral dysplasia': 0,
#  'Peutz Jeghers syndrome': 0,
#  'Woolly hair': 0,
#  'Anemia due to disorders of glutathione metabolism': 0,
#  'Naxos disease and Carvajal syndrome': 0,
#  'Monilethrix': 0,
#  'Netherton syndrome': 0,
#  'Pseudofolliculitis barbae': 0,
#  'Weill Marchesani syndrome': 0,
#  'Anemia due to disorders of nucleotide metabolism': 0,
#  'Acrocapitofemoral dysplasia': 0,
#  'Congenital primary aphakia': 0,
#  'Aplasia of lacrimal and salivary glands': 0,
#  'Achondrogenesis type IA': 0,
#  'Hypomyelinating leukodystrophy HLD': 0,
#  'Primary failure of tooth eruption': 0,
#  'Acne inversa': 1,
#  'Woodhouse Sakati syndrome': 0,
#  'Anonychia congenita': 0,
#  'Pachyonychia congenita': 1,
#  'Bifid nose with or without anorectal and renal anomalies': 0,
#  'Manitoba oculotrichoanal syndrome': 0,
#  'Fraser syndrome': 0,
#  'Familial advanced sleep phase syndrome': 0,
#  'Delayed sleep phase syndrome': 0,
#  'Aland Island eye disease': 0,
#  'Epidermolytic hyperkeratosis EHK': 0,
#  'Lowe syndrome': 0,
#  'Ichthyosis bullosa of Siemens': 0,
#  'Dent disease': 0,
#  'Mal de Meleda': 0,
#  'Haim Munk syndrome': 0,
#  'X linked myopathy with postural muscle atrophy XMPMA': 0,
#  'Nemaline myopathy': 0,
#  'Central core disease': 0,
#  'Centronuclear myopathy': 0,
#  'Congenital fiber type disproportion CFTD': 0,
#  'Cap myopathy': 0,
#  'Myosin storage myopathy MSM': 0,
#  'Oculopharyngeal muscular dystrophy OPMD': 0,
#  'Myotonia congenita': 2,
#  'Bart Pumphrey syndrome': 0,
#  'Ichthyosis hystrix Curth Macklin type': 0,
#  'Naegeli Franceschetti Jadassohn syndrome': 0,
#  'Birk Barel mental retardation syndrome BBMRS': 0,
#  'Erythrokeratodermia variabilis': 0,
#  'Russell Silver syndrome': 0,
#  'Keratitis ichthyosis deafness syndrome': 0,
#  'Beckwith Wiedemann syndrome': 0,
#  'Vohwinkel syndrome': 0,
#  'Darier disease': 7,
#  'Palmoplantar keratoderma with deafness': 0,
#  'Striate palmoplantar keratoderma': 0,
#  'Sotos syndrome and Weaver syndrome': 0,
#  'Leprechaunism': 0,
#  'Long QT syndrome': 20,
#  'Pyogenic bacterial infections recurrent due to MYD88 deficiency': 0,
#  'Epidermolytic palmoplantar keratoderma EPPK': 0,
#  'Non epidermolytic palmoplantar keratoderma NEPPK': 0,
#  'White sponge nevus': 0,
#  'Short QT syndrome': 4,
#  'Meesmann corneal dystrophy': 0,
#  'Bosley Salih Alorainy syndrome and Athabascan brainstem dysgenesis syndrome': 0,
#  'Brugada syndrome BRS': 0,
#  'Sick sinus syndrome SSS': 0,
#  'Familial idiopathic ventricular fibrillation': 0,
#  'Atrial fibrillation': 55,
#  'Sorsby fundus dystrophy': 0,
#  'Harlequin ichthyosis': 0,
#  'Lamellar ichthyosis LI and Non bullous congenital ichthyosiform erythroderma NBCIE': 0,
#  'Ichthyosis vulgaris': 0,
#  'Dorfman Chanarin syndrome': 0,
#  'Acral peeling skin syndrome': 0,
#  'Ichthyosis with confetti': 0,
#  'Ichthyosis with hypotrichosis': 0,
#  'Ichthyosis follicularis alopecia and photophobia syndrome': 0,
#  'Ichthyosis prematurity syndrome': 0,
#  'Neonatal ichthyosis sclerosing cholangitis NISCH syndrome': 0,
#  'Paramyotonia congenita PMC': 0,
#  'Potassium aggravated myotonias PAMs': 0,
#  'Hyperkalemic periodic paralysis HyperPP': 0,
#  'Hypokalemic periodic paralysis HypoPP': 0,
#  'Thyrotoxic hypokalemic periodic paralysis TPP': 0,
#  'Andersen Tawil syndrome ATS': 0,
#  'Episodic ataxias': 0,
#  'Keratosis follicularis spinulosa decalvans': 0,
#  'Asphyxiating thoracic dystrophy': 0,
#  'Ankyloblepharon ctodermal defects cleft lip palate AEC syndrome and Rapp Hodgkin syndrome': 0,
#  'Urofacial syndrome': 1,
#  '3 Methylglutaconic aciduria MGCA': 0,
#  'Acrokeratosis verruciformis': 0,
#  'Pitt Hopkins syndrome': 0,
#  'Dyggve Melchior Clausen disease and Smith McCort dysplasia': 0,
#  'Progressive pseudorheumatoid dysplasia PPRD': 0,
#  'Waardenburg syndrome WS': 0,
#  'Spondyloepiphyseal dysplasia tarda': 0,
#  'SEMD Pakistani type': 0,
#  'SEMD Omani type': 0,
#  'Transient bullous dermolysis of the newborn': 0,
#  'Cri du chat syndrome': 0,
#  'Spondyloepiphyseal dysplasia Kimberley type': 0,
#  'Wolcott Rallison syndrome': 0,
#  'SEMD Matrilin type': 0,
#  'Nonsyndromic autosomal recessive mental retardation NS ARMR': 0,
#  'Hyperekplexia': 3,
#  'Congenital myasthenic syndrome': 3,
#  'Inherited erythromelalgia IEM': 0,
#  'Paroxysmal extreme pain disorder PEPD': 0,
#  'Autosomal dominant mental retardation': 0,
#  'Nav1 7 associated congenital insensitivity to pain CIP': 0,
#  'Familial or sporadic hemiplegic migraine': 0,
#  'Congenital motor nystagmus CMN': 0,
#  'Spondylometaepiphyseal dysplasia short limb hand type': 0,
#  'Tarsal carpal coalition syndrome': 0,
#  'Usher syndrome US': 0,
#  'Atrichia with papular lesions': 0,
#  'Schopf Schulz Passarge syndrome': 0,
#  'Hypotrichosis and recurrent skin vesicles': 0,
#  'Febrile seizures': 2,
#  'Localized autosomal recessive hypotrichosis': 0,
#  'Congenital hypotrichosis with juvenile macular dystrophy': 0,
#  'Hypotrichosis simplex of scalp': 0,
#  'Congenital stationary night blindness CSNB': 0,
#  'Hoyeraal Hreidarsson syndrome': 0,
#  'Keratoconus': 5,
#  'Keratosis linearis with ichthyosis congenita and sclerosing keratoderma': 0,
#  'Disseminated superficial actinic porokeratosis DSAP': 0,
#  'Warburg micro syndrome': 0,
#  'Poikiloderma with neutropenia': 0,
#  'Aromatase excess syndrome': 1,
#  'Seborrhea like dermatitis with psoriasiform element': 0,
#  'Dermatopathia pigmentosa reticularis': 0,
#  'Martsolf syndrome': 0,
#  'Familial carpal tunnel syndrome': 0,
#  'Cerebral dysgenesis neuropathy ichthyosis and palmoplantar keratoderma syndrome': 0,
#  'Loeys Dietz syndrome LDS': 0,
#  'Familial thoracic aortic aneurysm and dissection TAAD': 0,
#  'Ehlers Danlos syndrome EDS': 0,
#  'Seizures sensorineural deafness ataxia mental retardation electrolyte imbalance SESAME': 0,
#  'Multiple cutaneous and uterine leiomyomata': 0,
#  'Vitreoretinal degeneration': 0,
#  'Benign familial neonatal and infantile epilepsies': 0,
#  'Autosomal dominant nocturnal frontal lobe epilepsy ADNFLE': 0,
#  'Idiopathic generalized epilepsies IGEs': 0,
#  'Autosomal dominant temporal lobe epilepsy ADTLE': 0,
#  'Progressive myoclonic epilepsy PME EPM': 0,
#  'Distal arthrogryposis DA': 0,
#  'Trichomoniasis': 3,
#  'Laryngo onycho cutaneous syndrome': 0,
#  'Vitelliform macular dystrophy': 0,
#  'Hyperpigmentation cutaneous with hypertrichosis hepatosplenomegaly heart anomalies hearing loss and hypogonadism': 0,
#  'Agenesis of the corpus callosum with peripheral neuropathy ACCPN': 0,
#  'Branchiooculofacial syndrome BOFS': 0,
#  'Birt Hogg Dube syndrome': 0,
#  'Stargardt disease STGD': 0,
#  'Bjornstad syndrome': 0,
#  'Macular degeneration': 0,
#  'Renal agenesis and Renal adysplasia': 0,
#  'ABCD syndrome': 0,
#  'Calcification of joints and arteries': 0,
#  'Familial flecked retina syndrome': 0,
#  'Blepharophimosis ptosis epicanthus inversus syndrome BPES': 0,
#  'Brooke Spiegler syndrome': 0,
#  'Familial cylindromatosis': 0,
#  'Multiple familial trichoepithelioma': 0,
#  'Alveolar capillary dysplasia with misalignment of pulmonary veins ACD MPV': 0,
#  'Primary dystonia': 0,
#  'Core neuroacanthocytosis syndromes': 0,
#  'Neurodegeneration with brain iron accumulation NBIA': 0,
#  'Guanidinoacetate methyltransferase GAMT deficiency': 0,
#  'Succinic semialdehyde dehydrogenase SSADH deficiency': 0,
#  'GLUT1 deficiency syndrome GLUT1DS': 0,
#  'Leber congenital amaurosis LCR': 0,
#  'Congenital fibrosis of the extraocular muscles CFEOM': 0,
#  'Porencephaly': 0,
#  'Band like calcification with simplified gyration and polymicrogyria BLC PMG': 0,
#  'Infantile progressive bulbar palsy': 0,
#  'Epidermodysplasia verruciformis': 2,
#  'Hartnup disorder': 0,
#  'Hailey Hailey disease': 0,
#  'Familial amyloidosis': 0,
#  'Fuhrmann syndrome': 0,
#  'Al Awadi Raas Rothschild syndrome': 0,
#  'Ataxia with ocular apraxia AOA': 0,
#  'Creatine deficiency syndrome': 0,
#  'Frontorhiny': 0,
#  'Synpolydactyly 2': 0,
#  'Klippel Feil syndrome KFS': 0,
#  'Cenani Lenz syndactyly syndrome': 0,
#  'Wolfram syndrome WFS': 0,
#  'Triphalangeal thumb': 0,
#  'Distal hereditary motor neuropathies dHMN': 0,
#  'Oligodontia colorectal cancer syndrome': 0,
#  'Marie Unna hereditary hypotrichosis MUHH': 0,
#  'Guttmacher syndrome': 0,
#  'Benign hereditary chorea': 0,
#  'Pancreatic agenesis': 0,
#  'Tourette syndrome': 27,
#  'Spondylo megaepiphyseal metaphyseal dysplasia': 0,
#  'Trichotillomania': 3,
#  'Lethal congenital contractural syndrome LCCS': 0,
#  'Trichothiodystrophy non photosensitive type 1 TTDN1': 0,
#  'Radioulnar synostosis with amegakaryocytic thrombocytopenia': 0,
#  'Stapes ankylosis with broad thumb and toes': 0,
#  'Leukoencephalopathy with vanishing white matter': 0,
#  'Brachydactyly syndactyly syndrome': 0,
#  'Leukoencephalopathy with brain stem and spinal cord involvement and lactate elevation LBSL': 0,
#  'Trismus pseudocamptodactyly syndrome': 0,
#  'Cousin syndrome': 0,
#  'Leukoencephalopathy with dystonia and motor neuropathy': 0,
#  'Megalencephalic leukoencephalopathy with subcortical cysts MLC': 0,
#  'Mismatch repair deficiency': 0,
#  'Brain small vessel disease with Axenfeld Rieger anomaly': 0,
#  'Cystic leukoencephalopathy without megalencephaly': 0,
#  'Perry syndrome': 0,
#  'Dyschromatosis symmetrica hereditaria': 0,
#  'Li Fraumeni syndrome': 0,
#  'Cocoon syndrome': 0,
#  'Lipoid proteinosis': 0,
#  'Familial progressive hyperpigmentation': 0,
#  'Hypomelanosis of Ito': 0,
#  'Donnai Barrow syndrome': 0,
#  'Lipoprotein glomerulopathy': 0,
#  'Nephrolithiasis osteoporosis hypophosphatemic': 0,
#  'MED12 related disorders': 0,
#  'Azoospermia': 0,
#  'Combined oxidative phosphorylation deficiency COXPD': 0,
#  'Bronchiectasis with or without elevated sweat chloride': 0,
#  'Skin fragility woolly hair syndrome': 0,
#  'FG syndrome FGS': 0,
#  'Basal cell nevus syndrome': 0,
#  'Lymphangioleiomyomatosis LAM': 0,
#  'Pontocerebellar hypoplasia': 0,
#  'Myopathy with lactic acidosis and sideroblastic anaemia MLASA': 0,
#  'Lysinuric protein intolerance LPI': 0,
#  'Geleophysic dysplasia': 0,
#  'Cystinuria': 8,
#  'Speech language disorder 1 SPCH1': 0,
#  'Congenital clubfoot': 0,
#  'Cutis laxa with severe pulmonary gastrointestinal and urinary abnormalities': 0,
#  'Iminoglycinuria': 0,
#  'Macrocephaly alopecia cutis laxa and scoliosis': 0,
#  'Kleefstra syndrome': 0,
#  'Mowat Wilson syndrome': 0,
#  'Cleft palate with ankyloglossia': 0,
#  'Hirschsprung disease HD': 0,
#  'Dicarboxylic aminoaciduria': 0,
#  'Tumor necrosis factor receptor associated periodic syndrome TRAPS': 0,
#  'Choreoathetosis hypothyroidism and neonatal respiratory distress': 0,
#  'Warsaw breakage syndrome': 0,
#  'Tuberous sclerosis complex TSC': 0,
#  'Congenital central hypoventilation syndrome CCHS': 0,
#  'Congenital dyserythropoietic anemias CDAs': 0,
#  'Conotruncal heart malformations': 0,
#  'Arterial tortuosity syndrome': 0,
#  'Exocrine pancreatic insufficiency dyserythropoietic anemia and calvarial hyperostosis': 0,
#  'Revesz syndrome': 0,
#  'Schinzel Giedion midface retraction syndrome': 0,
#  'Congenital systemic glutamine deficiency CSGD': 0,
#  'Severe combined immunodeficiency with microcephaly growth retardation and sensitivity to ionizing radiation': 0,
#  '2 Methyl 3 hydroxybutyryl CoA dehydrogenase MHBD deficiency': 0,
#  'Growth retardation developmental delay coarse facies and early death': 0,
#  'Chylomicron retention disease CRD': 0,
#  'Nephropathy with pretibial epidermolysis bullosa and deafness': 0,
#  'Congenital vertical talus': 0,
#  'Hypoalphalipoproteinemia': 0,
#  'Growth hormone insensitivity with immunodeficiency': 0,
#  'Tropical calcific pancreatitis': 0,
#  'Hereditary pancreatitis': 0,
#  'Caudal duplication anomaly': 0,
#  'Cold induced sweating syndrome CISS and Crisponi syndrome CRISPS': 0,
#  'Goldberg Shprintzen megacolon syndrome': 0,
#  'Precocious puberty': 1,
#  'Factor XI deficiency': 0,
#  'Neutropenia severe congenital 4 autosomal recessive': 0,
#  'Cohen syndrome': 0,
#  'Factor XII deficiency': 0,
#  'Rabson Mendenhall syndrome': 0,
#  'TARP syndrome': 0,
#  'Dowling Degos disease': 0,
#  'Factor XIII deficiency': 0,
#  'Arts syndrome': 0,
#  'Pilomatricoma': 0,
#  'Renal hypouricemia RHUC': 0,
#  'Focal dermal hypoplasia': 0,
#  'Arthrogryposis renal dysfunction and cholestasis': 0,
#  'Reis Bucklers corneal dystrophy RBCD': 0,
#  'Thiel Behnke dystrophies TBCD': 0,
#  'Gelatinous drop like corneal dystrophy GDCD': 0,
#  'Macular corneal dystrophy MCD': 0,
#  'Granular corneal dystrophies GCD': 0,
#  'Lattice corneal dystrophies LCD': 0,
#  'Fleck corneal dystrophy FCD': 0,
#  'Congenital stromal corneal dystrophy CSCD': 0,
#  'Schnyder corneal dystrophy SCD': 0,
#  'Fuchs corneal dystrophy FECD': 0,
#  'Posterior polymorphous corneal dystrophy PPCD': 0,
#  'RIDDLE syndrome': 0,
#  'Congenital hereditary endothelial dystrophy CHED': 0,
#  'Thiopurine S methyltransferase deficiency TPMT deficiency': 0,
#  'RAPADILINO syndrome': 0,
#  'AICA ribosiduria': 0,
#  'Adiponectin deficiency': 0,
#  'Raine syndrome': 0,
#  'Skeletal defects genital hypoplasia and mental retardation': 0,
#  'Juvenile primary lateral sclerosis': 0,
#  'Achromatopsia': 0,
#  'Endocrine cerebro osteodysplasia syndrome': 0,
#  'Bradyopsia': 0,
#  'Blue cone monochromacy': 0,
#  'Rotaviral enteritis': 0,
#  'Colorblindness': 0,
#  'Trichorhinophalangeal dysplasia': 0,
#  'Thrombocytopenia THC': 0,
#  'Caudal regression syndrome and Sirenomelia': 0,
#  'Nevo syndrome': 0,
#  'Ataxia with isolated vitamin E deficiency AVED': 0,
#  'Sideroblastic anemia': 0,
#  'Alpha 2 plasmin inhibitor a2 PI deficiency': 0,
#  'Bare lymphocyte syndrome BLS type1': 0,
#  'Bare lymphocyte syndrome BLS type2': 0,
#  'Multiple pterygium syndrome': 0,
#  'Fetal akinesia deformation sequence FADS': 0,
#  'Enterokinase deficiency': 0,
#  'Mohr Tranebjaerg syndrome': 0,
#  'Microcephaly Amish type': 0,
#  'Microcephalic osteodysplastic primordial dwarfism type II MOPD II': 0,
#  'Seckel syndrome': 0,
#  'Microcephalic osteodysplastic primordial dwarfism type I MOPD I': 0,
#  'Familial skewed X chromosome inactivation': 0,
#  'Combined deficiency of vitamin K dependent clotting factors VKCFD': 0,
#  'Amish infantile epilepsy syndrome': 0,
#  'CATSHL syndrome': 0,
#  'Alternating hemiplegia of childhood': 4,
#  'Coenzyme Q10 deficiency': 0,
#  'Retinal vasculopathy with cerebral leukodystrophy RVCL': 0,
#  'COACH syndrome': 0,
#  'Generalized arterial calcification of infancy': 0,
#  'Dimethylglycine dehydrogenase deficiency DMGDHD': 0,
#  'Velocardiofacial syndrome': 0,
#  'Dopamine beta hydroxylase deficiency': 0,
#  'Hereditary angioedema': 53,
#  'Choroid plexus papilloma': 0,
#  'C syndrome': 3,
#  'Newfoundland rod cone dystrophy NFRCD': 0,
#  'Occult macular dystrophy OMD': 0,
#  ...}

# %%
import json
with open("disease_abstract_count.json", "w") as outfile:
    json.dump(disease_abstract_count, outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
#       1 with open("disease_abstract_count.json", "w") as outfile:
# ----> 2     json.dump(disease_abstract_count, outfile)
#
# NameError: name 'json' is not defined
